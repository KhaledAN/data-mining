# %%
import pandas
import numpy as np
cols = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num']
url = './input/dataset.csv'
csvFile = pandas.read_csv(url, index_col=False, header=None, names=cols)
csvFile = csvFile.replace({'?': np.nan})

# %%
csvFile.dropna(inplace=True)
csvFile
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# 1      2.0  3.0  3.0    2
# 2      2.0  2.0  7.0    1
# 3      3.0  0.0  3.0    0
# 4      1.0  0.0  3.0    0
# ..     ...  ...  ...  ...
# 297    2.0  0.0  7.0    1
# 298    2.0  0.0  7.0    1
# 299    2.0  2.0  7.0    2
# 300    2.0  1.0  7.0    3
# 301    2.0  1.0  3.0    1
#
# [297 rows x 14 columns]

# %%
csvFile = csvFile.astype('float64')
csvFile
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  num
# 0      3.0  0.0   6.0  0.0
# 1      2.0  3.0   3.0  2.0
# 2      2.0  2.0   7.0  1.0
# 3      3.0  0.0   3.0  0.0
# 4      1.0  0.0   3.0  0.0
# ..     ...  ...   ...  ...
# 297    2.0  0.0   7.0  1.0
# 298    2.0  0.0   7.0  1.0
# 299    2.0  2.0   7.0  2.0
# 300    2.0  1.0   7.0  3.0
# 301    2.0  1.0   3.0  1.0
#
# [297 rows x 14 columns]

# %%
csvFile['num'] = csvFile['num'] > 0
csvFile
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal    num
# 0      3.0  0.0   6.0  False
# 1      2.0  3.0   3.0   True
# 2      2.0  2.0   7.0   True
# 3      3.0  0.0   3.0  False
# 4      1.0  0.0   3.0  False
# ..     ...  ...   ...    ...
# 297    2.0  0.0   7.0   True
# 298    2.0  0.0   7.0   True
# 299    2.0  2.0   7.0   True
# 300    2.0  1.0   7.0   True
# 301    2.0  1.0   3.0   True
#
# [297 rows x 14 columns]

# %%
csvFile['num'] = csvFile['num'].map({False: 0, True: 1})
csvFile
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  num
# 0      3.0  0.0   6.0    0
# 1      2.0  3.0   3.0    1
# 2      2.0  2.0   7.0    1
# 3      3.0  0.0   3.0    0
# 4      1.0  0.0   3.0    0
# ..     ...  ...   ...  ...
# 297    2.0  0.0   7.0    1
# 298    2.0  0.0   7.0    1
# 299    2.0  2.0   7.0    1
# 300    2.0  1.0   7.0    1
# 301    2.0  1.0   3.0    1
#
# [297 rows x 14 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import accuracy_score

dataFile = csvFile.copy()
y = dataFile.pop('num').values
x = pandas.DataFrame(scale(dataFile.values), columns=cols[0:13])
pca = PCA(n_components=2, svd_solver='full')
X_pca = pca.fit_transform(x)
X_Train, X_Test, Y_Train, Y_Test = train_test_split(
    X_pca, y, test_size=0.30, random_state=101)
hc = AgglomerativeClustering(
    n_clusters=2, affinity='euclidean', linkage='ward')
hierarchicalpredictions = hc.fit_predict(X_Test)
accuracy = accuracy_score(Y_Test, hierarchicalpredictions)
accuracy
# Out:
# 0.7666666666666667

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

sch.dendrogram(sch.linkage(X_Train, method='ward'))
plt.title('Hierarchical')
plt.savefig('result/hierarchical-dendrogram.png',
            dpi=520, format='png', bbox_inches='tight')
plt.show()

# %%
from sklearn.cluster import KMeans

dataFile = csvFile.copy()
Y = dataFile.pop('num').values
X = pandas.DataFrame(scale(dataFile.values), columns=cols[0:13])
kmeansRes = KMeans(n_clusters=2, init='k-means++', random_state=42)
kmeansRes.fit_predict(X)
accuracy = accuracy_score(Y, kmeansRes.predict(X))
accuracy
# Out:
# 0.8316498316498316

# %%
import seaborn as sns
data = X.copy()
data['cluster'] = kmeansRes.labels_

pca = PCA(n_components=2)
new_data = pca.fit_transform(data)
pca_df = pandas.DataFrame(
    new_data, columns=['X', 'Y'])

sns.scatterplot(x="X", y="Y",
                hue=data['cluster'], data=pca_df)
plt.title('K-means')
plt.savefig('result/kmeans_result.png')
plt.show()

# %%
csvFile.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    3.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    1.602694    0.676768
# std      0.994914   22.941562    0.469761    1.166123    0.618187    0.938965
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.000000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000
#
#              thal         num
# count  297.000000  297.000000
# mean     4.730640    0.461279
# std      1.938629    0.499340
# min      3.000000    0.000000
# 25%      3.000000    0.000000
# 50%      3.000000    0.000000
# 75%      7.000000    1.000000
# max      7.000000    1.000000

# %%
csvFile.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# Length: 297, dtype: bool

# %%
csvFile.num.value_counts(normalize=True)
csvFile.num.value_counts(normalize=True).plot.barh()
plt.show()

# %%
csvFile.plot.scatter(x="age",y="num")
plt.show()

# %%
sns.heatmap(csvFile[['age','sex','cp','chol']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
sns.heatmap(csvFile[['slope','ca','thal']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
sns.heatmap(csvFile[['thalach','exang','oldpeak']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
sns.heatmap(csvFile[['trestbps','fbs','restecg']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
sns.heatmap(csvFile[['age','sex','cp','chol']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
csvFile.groupby('age')['num'].mean().plot.bar()
plt.show()
